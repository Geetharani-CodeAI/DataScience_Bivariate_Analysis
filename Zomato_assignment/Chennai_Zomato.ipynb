# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.io as pio
import plotly.express as px

# %%
df = pd.read_csv("Zomato_Chennai.csv")
df
# Out:
#                                               Zomato URL  \
# 0      https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1      https://www.zomato.com/chennai/sukkubhai-biriy...
# 2      https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3            https://www.zomato.com/chennai/kfc-perambur
# 4      https://www.zomato.com/chennai/tasty-kitchen-p...
# ...                                                  ...
# 12027  https://www.zomato.com/chennai/cks-sandwiches-...
# 12028  https://www.zomato.com/chennai/cks-sandwiches-...
# 12029  https://www.zomato.com/chennai/cks-sandwiches-...
# 12030  https://www.zomato.com/chennai/cks-sandwiches-...
# 12031  https://www.zomato.com/chennai/cks-sandwiches-...
#
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# ...

# %% [markdown]
# # 1) Basic Information about the dataset

# %%
df.shape
# Out:
# (12032, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zomato URL             12032 non-null  object
#  1   Name of Restaurant     12032 non-null  object
#  2   Address                12032 non-null  object
#  3   Location               12032 non-null  object
#  4   Cuisine                12032 non-null  object
#  5   Top Dishes             12032 non-null  object
#  6   Price for 2            12032 non-null  float64
#  7   Dining Rating          6681 non-null   float64
#  8   Dining Rating Count    11812 non-null  object
#  9   Delivery Rating        6181 non-null   float64
#  10  Delivery Rating Count  11812 non-null  object
#  11  Features               12032 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#         Price for 2  Dining Rating  Delivery Rating
# count  12032.000000    6681.000000      6181.000000
# mean     397.611370       3.387756         3.805290
# std      332.045938       0.558181         0.374213
# min       40.000000       0.300000         0.300000
# 25%      200.000000       3.100000         3.600000
# 50%      300.000000       3.500000         3.900000
# 75%      450.000000       3.800000         4.000000
# max     5000.000000       4.900000         4.700000

# %% [markdown]
# # 2) Data Cleaning

# %% [markdown]
# #### a)Dropping the redundant columns:

# %%
# Dropping Unnecessary URl column for analysis

df.drop(['Zomato URL'], axis = 1, inplace = True)

# %%
df
# Out:
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# 12029        CK's Sandwiches
# 12030        CK's Sandwiches
# 12031        CK's Sandwiches
#
#                                                  Address         Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai       Pallavaram
# 1       New 14, Old 11/3Q, Railway Station Road, MKN ...          Alandur
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...      Kodambakkam
# 3       10, Periyar Nagar, 70 Feet Road, Near Sheeba ...         Perambur
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...         Perambur
# ...                                                  ...              ...
# 12027                                      Delivery Only            Porur
# ...

# %%
df.rename(columns = {'Price for 2':'Price'},inplace = True)

# %% [markdown]
# #### b) Handling Null values

# %%
df.isnull().sum()
# Out:
# Name of Restaurant          0
# Address                     0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price                       0
# Dining Rating            5351
# Dining Rating Count       220
# Delivery Rating          5851
# Delivery Rating Count     220
# Features                    0
# dtype: int64

# %%
# Replacing nulls with 'NA'

df.dropna(inplace = True)
df.isnull().sum()
# Out:
# Name of Restaurant       0
# Address                  0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price                    0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %% [markdown]
# #### c) Converting any non-numerical values into Numerical datatypes

# %%
df['Dining Rating'].value_counts()
# Out:
# Dining Rating
# 3.7    387
# 3.6    377
# 3.5    359
# 3.8    334
# 3.4    324
# 3.9    301
# 3.3    294
# 3.2    262
# 3.1    236
# 4.0    222
# 3.0    192
# 4.1    166
# 2.9    161
# 2.8    120
# 2.0    111
# 4.2    105
# 4.3     87
# 2.7     78
# 2.6     56
# 2.5     44
# 4.4     41
# 2.4     26
# 4.5     26
# 2.3     18
# 2.2     12
# 4.6     11
# 4.7      9
# 4.9      7
# 2.1      6
# 4.8      3
# 1.9      3
# 1.7      2
# 0.3      1
# Name: count, dtype: int64

# %%
df['Delivery Rating'].value_counts()
# Out:
# Delivery Rating
# 3.9    939
# 3.8    530
# 4.0    437
# 3.7    411
# 4.1    356
# 3.6    330
# 4.2    304
# 3.5    220
# 4.3    219
# 3.4    169
# 3.3    118
# 4.4     98
# 3.2     61
# 3.1     44
# 4.5     43
# 3.0     31
# 2.9     17
# 4.6     16
# 2.8      8
# 2.6      6
# 2.7      5
# 1.8      5
# 2.4      3
# 4.7      3
# 2.2      3
# 2.1      2
# 2.3      1
# 1.6      1
# 1.5      1
# Name: count, dtype: int64

# %%
df['Dining Rating Count'].value_counts()
# Out:
# Dining Rating Count
# 4      104
# 6       98
# 5       88
# 9       85
# 8       81
#       ...
# 848      1
# 999      1
# 688      1
# 627      1
# 224      1
# Name: count, Length: 748, dtype: int64

# %%
df['Delivery Rating Count'].value_counts()
# Out:
# Delivery Rating Count
# 51      24
# 48      20
# 46      19
# 60      18
# 45      18
#         ..
# 2188     1
# 9239     1
# 867      1
# 1189     1
# 1617     1
# Name: count, Length: 2030, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4381 entries, 0 to 11794
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name of Restaurant     4381 non-null   object
#  1   Address                4381 non-null   object
#  2   Location               4381 non-null   object
#  3   Cuisine                4381 non-null   object
#  4   Top Dishes             4381 non-null   object
#  5   Price                  4381 non-null   float64
#  6   Dining Rating          4381 non-null   float64
#  7   Dining Rating Count    4381 non-null   object
#  8   Delivery Rating        4381 non-null   float64
#  9   Delivery Rating Count  4381 non-null   object
#  10  Features               4381 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 410.7+ KB

# %%
df['Dining Rating'] = df['Dining Rating'].astype('float64')
df['Dining Rating Count'] = df['Dining Rating'].astype('int64')
df['Delivery Rating'] = df['Dining Rating'].astype('float64')
df['Delivery Rating Count'] = df['Dining Rating'].astype('int64')

# %% [markdown]
# #### d) Working with Location Column

# %%
df['Location'].value_counts()
# Out:
# Location
# Porur                                      148
# Anna Nagar East                            146
# Velachery                                  145
# Ambattur                                   124
# T. Nagar                                   119
#                                           ...
# Holiday Inn Chennai OMR IT Expressway        1
# Chennai Food Town, Thuraipakkam              1
# Foodies Kitchen                              1
# Hotel Bhimaas, Vadapalani                    1
# Spectrum The Grand Venus Mall, Perambur      1
# Name: count, Length: 161, dtype: int64

# %%
# splitting the location column and storing it in a temp df

temp_df = df['Location'].str.split(',', n =1, expand = True)
temp_df
# Out:
#                  0     1
# 0       Pallavaram  None
# 1          Alandur  None
# 2      Kodambakkam  None
# 3         Perambur  None
# 4         Perambur  None
# ...            ...   ...
# 11666      Alandur  None
# 11667   Palavakkam  None
# 11736        Porur  None
# 11785     Ambattur  None
# 11794   Karapakkam  None
#
# [4381 rows x 2 columns]

# %%
df['Location'] = temp_df[0]
df['Location']
# Out:
# 0         Pallavaram
# 1            Alandur
# 2        Kodambakkam
# 3           Perambur
# 4           Perambur
#             ...
# 11666        Alandur
# 11667     Palavakkam
# 11736          Porur
# 11785       Ambattur
# 11794     Karapakkam
# Name: Location, Length: 4381, dtype: object

# %% [markdown]
# #### e) Removing duplicates

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [Name of Restaurant, Address, Location, Cuisine, Top Dishes, Price, Dining Rating, Dining Rating Count, Delivery Rating, Delivery Rating Count, Features]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                        Name of Restaurant  \
# 0                   Yaa Mohaideen Briyani
# 1                      Sukkubhai Biriyani
# 2                    SS Hyderabad Biryani
# 3                                     KFC
# 4                           Tasty Kitchen
# ...                                   ...
# 11666                         Juice World
# 11667                         Juice World
# 11736  Adyar Vaishnavas Thattu Idly Kadai
# 11785                   Engineers Kitchen
# 11794                     That Juice Shop
#
#                                                  Address     Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1       New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3       10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
# ...

# %% [markdown]
# #### f) Removing Dining Rating or Delivery Rating is 0

# %%
useless_data = (df['Dining Rating'] == 0)|(df['Delivery Rating'] == 0)
df = df[~useless_data]

# %%
# Removing Invalid columns in all columns

df = df[df.ne('Invalid').all(axis=1)]
df
# Out:
#            Name of Restaurant  \
# 0       Yaa Mohaideen Briyani
# 1          Sukkubhai Biriyani
# 2        SS Hyderabad Biryani
# 3                         KFC
# 4               Tasty Kitchen
# ...                       ...
# 10867  Perambur Sri Srinivasa
# 10964              Hot Breads
# 11035          Uzo Sandwiches
# 11080          The Cake World
# 11134       Nandhiniee Sweets
#
#                                                  Address     Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai   Pallavaram
# 1       New 14, Old 11/3Q, Railway Station Road, MKN ...      Alandur
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...  Kodambakkam
# 3       10, Periyar Nagar, 70 Feet Road, Near Sheeba ...     Perambur
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...     Perambur
# ...                                                  ...          ...
# 10867              98, MTH Road, Padi, Ambattur, Chennai     Ambattur
# ...

# %% [markdown]
# # 5. Performing Exploratory Data Analysis

# %% [markdown]
# #### 1. Which are the Top 10 highest rated Biryani Restaurant in Chennai?

# %%
biryani_df = df[df['Cuisine'].str.contains('Biryani')]
biryani_df.head()
# Out:
#         Name of Restaurant                                            Address  \
# 0    Yaa Mohaideen Briyani          336 & 338, Main Road, Pallavaram, Chennai
# 1       Sukkubhai Biriyani   New 14, Old 11/3Q, Railway Station Road, MKN ...
# 2     SS Hyderabad Biryani   98/339, Arcot Road, Opposite Gokulam Chit Fun...
# 4            Tasty Kitchen   135B, SRP Colony, Peravallur, Near Perambur, ...
# 13  Dindigul Thalappakatti               New 21-A, Arcot Road, Porur, Chennai
#
#        Location                                            Cuisine  \
# 0    Pallavaram                                        ['Biryani']
# 1       Alandur  ['Biryani', ' North Indian', ' Mughlai', ' Des...
# 2   Kodambakkam  ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 4      Perambur  ['Chinese', ' Biryani', ' North Indian', ' Che...
# 13        Porur  ['South Indian', ' Biryani', ' Chinese', ' Nor...
#
#                                            Top Dishes   Price  Dining Rating  \
# ...

# %% [markdown]
# #### 2. How many restaurant have Mutton Biryani?

# %%
Mbiryani_df = df[df['Top Dishes'].str.contains('Mutton Biryani')]
Mbiryani_df
# Out:
#            Name of Restaurant  \
# 0       Yaa Mohaideen Briyani
# 2        SS Hyderabad Biryani
# 4               Tasty Kitchen
# 11        Kovai Alankar Vilas
# 13     Dindigul Thalappakatti
# ...                       ...
# 9693       Ambur Star Biryani
# 9769          Rahman Biriyani
# 10047                 Al Reef
# 10280         Qurbani Biryani
# 10458           Bismi Briyani
#
#                                                  Address         Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai       Pallavaram
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...      Kodambakkam
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...         Perambur
# 11          AC 3, 2nd Avenue, Anna Nagar East, Chennai .  Anna Nagar East
# 13                  New 21-A, Arcot Road, Porur, Chennai            Porur
# ...                                                  ...              ...
# 9693    3/88, Mount Ponamallee High Road, Near DLF Ma...        Ramapuram
# ...

# %% [markdown]
# #### 3. What are the percentage of restaurants  by Dining Rating in Chennai?

# %%
dining_rating_df = df['Dining Rating'].value_counts().reset_index()
dining_rating_df.rename(columns ={'count':'Count of Restaurants'})
# Out:
#     Dining Rating  Count of Restaurants
# 0             3.9                   222
# 1             4.0                   197
# 2             3.8                   174
# 3             4.1                   160
# 4             3.7                   121
# 5             4.2                   104
# 6             3.6                    93
# 7             4.3                    85
# 8             3.5                    53
# 9             3.4                    51
# 10            3.3                    45
# 11            3.0                    43
# 12            3.2                    40
# 13            3.1                    40
# 14            4.4                    39
# 15            2.9                    35
# 16            4.5                    26
# 17            2.6                    22
# 18            2.7                    21
# 19            2.8                    20
# 20            2.5                    20
# 21            2.4                    13
# ...

# %%
sns.jointplot(dining_rating_df, x = 'Dining Rating', y = 'count', kind = 'hex')
plt.show()

# %% [markdown]
# #### 4. Restaurants have Car Parking features in Chennai?

# %%
park_df = df[df['Features'].str.contains('Free Parking')]
park_df.sort_values(by = 'Dining Rating',ascending = False)
# Out:
#                             Name of Restaurant  \
# 320                               Bombay Kulfi
# 184                       Gossip Fusion Bistro
# 155                          The Sandwich Shop
# 163           Momo Sa-Khang by Kailash Kitchen
# 37                                Shree Mithai
# ...                                        ...
# 9619                                  Anjappar
# 1082   Madurai Kannappar Chettinadu Restaurant
# 10497              The Grand Sweets and Snacks
# 10044                                  Al Reef
# 9614                                  Anjappar
#
#                                                  Address       Location  \
# 320     4/2, 10th Cross Street, Indira Nagar, Adyar, ...          Adyar
# 184     New 141, Old 191, Opposite HP Fuel Station, E...       Kanathur
# 155              1, Subba Street, West Mambalam, Chennai  West Mambalam
# 163     2/247, Perinbavilas Complex, Opposite Chitra ...    Choolaimedu
# ...

# %% [markdown]
# #### 5. Which Restaurant has high dining rated and low price?

# %%
high_dining_df = df[df['Dining Rating'] >= 4.5]
high_dining_df.head()
# Out:
#    Name of Restaurant                                            Address  \
# 24     Eating Circles            6, CP Ramaswamy Road, Alwarpet, Chennai
# 37       Shree Mithai                   18, Dr TV Road, Chetpet, Chennai
# 50        Andhikkadai    20, Dhandeeswaram Main Road, Velachery, Chennai
# 57     Brownie Heaven   193, Peters Road, Opposite New College, Royap...
# 59              Mezze   Abhinav Center, Old Number 19, New Number 4, ...
#
#       Location                                   Cuisine  \
# 24    Alwarpet                          ['South Indian']
# 37     Chetpet  ['Mithai', ' Street Food', ' Fast Food']
# 50   Velachery                          ['South Indian']
# 57  Royapettah     ['Bakery', ' Desserts', ' Beverages']
# 59    Alwarpet                        ['Middle Eastern']
#
#                                            Top Dishes  Price  Dining Rating  \
# 24  ['Rose Milk', ' Neer Dosa', ' Thatte Idli', ' ...  250.0            4.7
# ...

# %%
print((df['Price'].max())/5)
# Out:
# 600.0

# %%
# Low Price means below mean value

low_price_df = df[['Name of Restaurant','Location','Cuisine','Top Dishes','Price','Dining Rating','Dining Rating Count']]
low_price_df = low_price_df[low_price_df['Price'] <= 600 ]
low_price_df
# Out:
#            Name of Restaurant     Location  \
# 0       Yaa Mohaideen Briyani   Pallavaram
# 2        SS Hyderabad Biryani  Kodambakkam
# 3                         KFC     Perambur
# 4               Tasty Kitchen     Perambur
# 5                  Dine N Fun   Medavakkam
# ...                       ...          ...
# 10867  Perambur Sri Srinivasa     Ambattur
# 10964              Hot Breads     T. Nagar
# 11035          Uzo Sandwiches      Potheri
# 11080          The Cake World    Velachery
# 11134       Nandhiniee Sweets     T. Nagar
#
#                                                  Cuisine  \
# 0                                            ['Biryani']
# 2      ['Biryani', ' North Indian', ' Chinese', ' Ara...
# 3      ['Burger', ' Fast Food', ' Finger Food', ' Bev...
# 4      ['Chinese', ' Biryani', ' North Indian', ' Che...
# 5          ['South Indian', ' North Indian', ' Chinese']
# ...                                                  ...
# ...

# %%
# MERGING high_dining_rating and less price df

high_ratelow_df = pd.merge(high_dining_df, low_price_df, how = 'inner', on = ['Name of Restaurant','Location'])
high_ratelow_df = high_ratelow_df[['Name of Restaurant','Price_x','Cuisine_x','Location','Top Dishes_x','Dining Rating_x','Dining Rating Count_x']] # suffix appears automatically while doing merge
high_ratelow_df.rename(columns = {'Name of Restaurant':'Name of Restaurant','Price_x':'Price','Cuisine_x':'Cuisine',
                                   'Top Dishes_x':'Top Dishes','Dining Rating_x':'Dining Rating','Dining Rating Count_x':'Dining Rating Count'},inplace = True)

# %%
# High rated Low Price Affordable Restaurant
high_ratelow_df
# Out:
#                     Name of Restaurant  Price  \
# 0                       Eating Circles  250.0
# 1                         Shree Mithai  300.0
# 2                          Andhikkadai  200.0
# 3                       Brownie Heaven  350.0
# 4   Amadora Gourmet Ice Cream & Sorbet  500.0
# 5                      Fusilli Reasons  400.0
# 6                Shri Rajasthani Dhaba  500.0
# 7            Fruit Shop On Greams Road  350.0
# 8                         Rayar's Mess  100.0
# 9                   North East Kitchen  450.0
# 10                   The Sandwich Shop  300.0
# 11                           BurgerMan  450.0
# 12    Momo Sa-Khang by Kailash Kitchen  350.0
# 13                 Royal Sandwich Shop  150.0
# 14                        Kabab Corner  450.0
# 15                         Cream Stone  350.0
# 16               Prems Graama Bhojanam  500.0
# 17          Shyam's Bombay Halwa House  600.0
# 18                        Krispy Kreme  400.0
# ...

# %%
fig = px.histogram(high_dining_df,x = 'Location', color = 'Cuisine',
                  title = 'No. of Best Restaurant for each Cuisine Type by Places').update_xaxes(categoryorder='total descending')
fig.show()

# %% [markdown]
# #### 6. How many High Rated Vegetarian Only Restaurants in Chennai?

# %%
veg_df = df[df['Features'].str.contains('Vegetarian Only')]
veg_df
# Out:
#              Name of Restaurant  \
# 9      Sangeetha Veg Restaurant
# 24               Eating Circles
# 27         Bakya Veg Restaurant
# 31              Nithya Amirtham
# 32         Shri Balaajee Bhavan
# ...                         ...
# 10539               Kulfi House
# 10560              Ganga Sweets
# 10667        Sri Krishna Sweets
# 10867    Perambur Sri Srinivasa
# 11134         Nandhiniee Sweets
#
#                                                  Address       Location  \
# 9              102/82, GN Chetty Road, T. Nagar, Chennai       T. Nagar
# 24               6, CP Ramaswamy Road, Alwarpet, Chennai       Alwarpet
# 27      20, Jaishankar Street, Near Ayodhya Mandapam,...  West Mambalam
# 31      39, North Mada Street, Near Kapaleeswarar Tem...       Mylapore
# 32      412/07, Thoraipakam Road Over Bridge, Chromep...      Chromepet
# ...                                                  ...            ...
# ...

# %%
veg_dining_df = veg_df[veg_df['Dining Rating'] >= 4.5]
veg_dining_df
# Out:
#                       Name of Restaurant  \
# 24                        Eating Circles
# 37                          Shree Mithai
# 50                           Andhikkadai
# 70                          Little Italy
# 75                       Fusilli Reasons
# 78                 Shri Rajasthani Dhaba
# 92             Fruit Shop On Greams Road
# 108                         Rayar's Mess
# 110                         VB Signature
# 155                    The Sandwich Shop
# 156                            SpiceKlub
# 209                          Cream Stone
# 219                Prems Graama Bhojanam
# 234                                Hamsa
# 242           Shyam's Bombay Halwa House
# 255                         Krispy Kreme
# 270                                   ID
# 471   Shmoozie's Hand-Crafted Ice Creams
# 9123                        Little Italy
# 9273                          Ratna Cafe
# 9363                         Flower Drum
# 9367                         Cream Stone
#
# ...

# %%
fig = px.scatter(veg_dining_df, x = 'Location', y = 'Price', color = 'Cuisine', symbol='Cuisine',
                title = "Avg Price Distribution of High rated Vegetarian Restaurant for each Cuisine Type").update_traces(marker_size =10)
fig.show()

# %% [markdown]
# #### 7. How many Restaurant has Mexican Style Cuisine?

# %%
mexi_df = df[df['Cuisine'].str.contains('Mexican')]
mexi_df
# Out:
#             Name of Restaurant  \
# 70                Little Italy
# 170                   The Bark
# 182                       Tovo
# 203               Cafe Central
# 280                       Hola
# 316           Prive Restaurant
# 476   The Little White Kitchen
# 481                      Mozza
# 577         The Chocolate Room
# 614                   Rajputra
# 652                   Wrapsody
# 674          Zest Live Kitchen
# 2757        Real Pizza Corrner
# 9123              Little Italy
# 9124              Little Italy
# 9384               Bistro 1427
# 9385               Bistro 1427
# 9386               Bistro 1427
#
#                                                 Address         Location  \
# 70     E-50, 17th Cross Street, Lane Before Spencers...     Besant Nagar
# 170    40, Maharaja Surya Rao Road, Dutch Village, A...         Alwarpet
# 182                   113, R K Salai, Mylapore, Chennai         Mylapore
# ...

# %%
fig = px.bar(mexi_df, x = 'Location', y = 'Delivery Rating', color = 'Price', title = 'Mexican Restaurants in Chennai')
fig.show()

# %% [markdown]
# #### 8. Is there a relation between Price and Dining Rating by each Cuisine Type?

# %%
price_dining_df = df.groupby(['Cuisine','Dining Rating'])['Price'].mean().reset_index()
price_dining_df
# Out:
#                                                 Cuisine  Dining Rating   Price
# 0     ['American', ' Continental', ' European', ' It...            3.9   700.0
# 1     ['American', ' Continental', ' Italian', ' Nor...            4.1   800.0
# 2                          ['American', ' Continental']            4.1  1600.0
# 3                            ['American', ' Fast Food']            3.9   500.0
# 4     ['American', ' Mexican', ' Steak', ' Beverages...            4.4  1600.0
# ...                                                 ...            ...     ...
# 1331                  ['Tibetan', ' Chinese', ' Momos']            4.1   250.0
# 1332                            ['Tibetan', ' Chinese']            3.8   450.0
# 1333                            ['Tibetan', ' Chinese']            4.2   350.0
# 1334                              ['Tibetan', ' Momos']            3.6   400.0
# 1335                              ['Turkish', ' Kebab']            4.3   500.0
#
# [1336 rows x 3 columns]

# %%
fig = px.scatter(price_dining_df, x = 'Dining Rating', y = 'Price', color = 'Cuisine')
fig.show()

# %% [markdown]
# #### 9. Restaurants with Valet Parking

# %%
valet_df = df[df['Features'].str.contains('Valet Parking')]
valet_df.groupby(by = 'Location').agg({'Name of Restaurant':'count','Price':'mean'}).reset_index().rename(columns = {'Name of Restaurant':'Count'})
# Out:
#                                  Location  Count        Price
# 0                                   Adyar      7  1042.857143
# 1                                 Akkarai      2   575.000000
# 2                                Alwarpet      4   825.000000
# 3                           Ambica Empire      1  1000.000000
# 4                         Anna Nagar East      7   978.571429
# 5                         Anna Nagar West      1  1500.000000
# 6                             Ashok Nagar      5   800.000000
# 7                              Benzz Park      1   850.000000
# 8                            Besant Nagar      3   983.333333
# 9                                 Chetpet      2   900.000000
# 10                              Chromepet      1   750.000000
# 11                  East Coast Road (ECR)      1  2000.000000
# 12                                Egatoor      2   775.000000
# 13                                 Egmore      2   625.000000
# ...

# %%
fig = px.histogram(valet_df, x ='Location', color = 'Price', 
        title = 'No. of Restaurants by Valet Parking', labels = {'Count':'Count'})
fig.show()

# %% [markdown]
# #### Q10) What are the percentage of Restaurants by Rating Type in Chennai?

# %%
dining_rating_df = df['Dining Rating'].value_counts().reset_index()
dining_rating_df.rename(columns = {'index':'Dining Rating', 'count': 'Count of Restaurant'},inplace = True)
dining_rating_df
# Out:
#     Dining Rating  Count of Restaurant
# 0             3.9                  222
# 1             4.0                  197
# 2             3.8                  174
# 3             4.1                  160
# 4             3.7                  121
# 5             4.2                  104
# 6             3.6                   93
# 7             4.3                   85
# 8             3.5                   53
# 9             3.4                   51
# 10            3.3                   45
# 11            3.0                   43
# 12            3.2                   40
# 13            3.1                   40
# 14            4.4                   39
# 15            2.9                   35
# 16            4.5                   26
# 17            2.6                   22
# 18            2.7                   21
# 19            2.8                   20
# 20            2.5                   20
# 21            2.4                   13
# 22            4.6                   11
# ...

# %%
fig = px.pie(dining_rating_df, names = 'Dining Rating', values = 'Count of Restaurant', color = 'Dining Rating', 
            title = 'Percentage of Restaurants by Dining Rating').update_traces(textposition='inside', textinfo = 'percent+label')
fig.show()
